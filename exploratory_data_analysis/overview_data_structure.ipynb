# %%
from figure_making import data_loader

# %%
example_animal = 'SZ036'
example_session_id = 10
df = data_loader.load_session_dataframe(example_animal, 'DA_vs_features', session_id=example_session_id, session_long_name=None, file_format='parquet')
print(df.head())
print(df.columns)
# Out:
# Loading: c:\Users\shich\OneDrive - Johns Hopkins\ShulerLab\TemporalDecisionMaking\imaging_during_task\SZ036\processed_data\SZ036_2024-01-10T12_41_DA_vs_features.parquet
# session: SZ036_2024-01-10T12_41_D
#   hemisphere       NRI       IRI block        DA
# 0      right  1.100632  0.400102   0.8  2.277213
# 1      right  1.800676  0.700314   0.8  1.875568
# 2      right  2.500633  0.700225   0.8  1.390982
# 3      right  3.300691  0.800365   0.8  2.852691
# 4      right  0.300593  4.474519   0.8  1.063626
# Index(['hemisphere', 'NRI', 'IRI', 'block', 'DA'], dtype='object')
