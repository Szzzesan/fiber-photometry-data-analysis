# %%
from figure_making import data_loader

# %%
example_animal = 'SZ036'
example_session_id = 10
df = data_loader.load_session_dataframe(example_animal, 'DA_vs_lastR_df', session_id=example_session_id, session_long_name=None, file_format='parquet')
print(df.head())
print(df.columns)
# Out:
# Loading: c:\Users\shich\OneDrive - Johns Hopkins\ShulerLab\TemporalDecisionMaking\imaging_during_task\SZ036\processed_data\SZ036_2024-01-10T12_41_DA_vs_lastR_df.parquet
# session: SZ036_2024-01-10T12_41_D
#    trial block  last_reward_time  reward_time  next_reward_time  time_in_port  \
# 0    1.0   0.8         19.132284    21.032982               NaN      5.200661
# 1    2.0   0.8         42.767865    42.967980               NaN      9.500606
# 2    3.0   0.8         61.111204    63.512131               NaN      8.700919
# 3    4.0   0.8         79.422034    82.523226               NaN      8.600538
# 4    5.0   0.8        100.732099   100.932193               NaN      6.800585
#
#    IRI_prior  IRI_post  entry_time   exit_time  recent_reward_rate  \
# 0   1.900698       NaN   15.830356   23.355597            0.427899
# 1   0.200115       NaN   33.463767   46.535331            0.533333
# 2   2.400927       NaN   54.807886   66.469862            0.533333
# ...
