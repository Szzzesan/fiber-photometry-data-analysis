# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from figure_making import data_loader

# %%
animal_ids = ["SZ036", "SZ037", "SZ038", "SZ039", "SZ042", "SZ043"]
master_df1 = data_loader.load_dataframes_for_animal_summary(animal_ids, 'bg_trial_df',
                                                            day_0='2023-11-30', hemisphere_qc=0, file_format='parquet')

animal_ids = ["RK007", "RK008"]
master_df2 = data_loader.load_dataframes_for_animal_summary(animal_ids, 'bg_trial_df',
                                                            day_0='2025-06-17', hemisphere_qc=0, file_format='parquet')
# Out:
#    trial phase      entry       exit  \
# 0    1.0   0.8   5.995880  17.290021
# 1    2.0   0.8  28.104886  35.090414
# 2    3.0   0.8  45.765665  51.941317
# 3    4.0   0.8  64.321695  77.026311
# 4    5.0   0.8  87.880442  93.443385
#
#                                                licks  \
# 0  [7.004536122605205, 7.128399776518345, 11.2547...
# 1  [28.28176049707085, 28.40414834578335, 28.5217...
# 2  [45.9461142661199, 46.06299407970905, 46.17714...
# 3  [71.28054299952835, 71.37693850325049, 71.4787...
# 4  [88.05617345380038, 88.1786056625247, 88.29602...
#
#                                              rewards  \
# 0  [11.641885757990181, 12.892284378834068, 14.14...
# 1  [29.355974496498703, 30.606367870457472, 31.85...
# 2  [47.01675036804378, 48.267189056001605, 49.517...
# 3  [72.25218328999728, 73.50260122890771, 74.7530...
# 4  [89.13132426041365, 90.38164823240787, 91.6320...
#
#                             excess_entries          excess_exits animal  \
# ...
